# %%
import pandas as pd
import seaborn as sns

# %%
assel = pd.read_csv('assel_data2.csv', sep=';')

# %%
assel
# Out:
#     age  gender marital status kids        education           job house  \
# 0    30  female        married  yes  Bachelor Degree  sales person    no
# 1    44    male        married  yes   Masters Degree       teacher   yes
# 2    30    male         single   no              MBA        doctor    no
# 3    20    male         single   no          Student       student    no
# 4    33  female       divorced  yes  Bachelor Degree     housemaid   yes
# 5    21  female        married   no  College Diploma       teacher    no
# 6    26    male         single   no   Masters Degree        doctor    no
# 7    20  female         single   no          Student       student    no
# 8    37  female        married  yes  College Diploma     housemaid   yes
# 9    34    male       divorced  yes              MBA      marketer   yes
# 10   30    male         single   no   Masters Degree      marketer    no
# 11   45    male        married  yes   Masters Degree    technician   yes
# 12   56  female        married  yes   Masters Degree       service   yes
# 13   59  female         single  yes  Bachelor Degree       service   yes
# 14   30    male        married   no   Masters Degree        admin.    no
# 15   29    male        married   no  Bachelor Degree    technician    no
# 16   25  female         single  yes  Bachelor Degree        admin.    no
# 17   48    male         single   no      High School   blue-collar   yes
# 18   40    male       divorced  yes  College Diploma    unemployed   yes
# 19   30  female       divorced  yes      High School    unemployed    no
# 20   31  female        married  yes  Bachelor Degree        admin.   yes
# 21   33    male        married  yes  Bachelor Degree    management   yes
# 22   55    male        married  yes              MBA  enterpreneur   yes
# 23   25    male         single   no  Bachelor Degree  enterpreneur    no
# 24   24    male         single   no  Bachelor Degree        admin.    no
# 25   63  female       divorced  yes      High School     housemaid   yes
# 26   48  female        married  yes   Masters Degree    management   yes
# 27   38  female         single   no   Masters Degree    management   yes
# 28   30  female        married   no  College Diploma       service    no
# 29   29    male       divorced   no      High School   blue-collar    no
# ..  ...     ...            ...  ...              ...           ...   ...
# 69   38    male        married  yes  Bachelor Degree     housemaid   yes
# 70   33  female         single   no   Masters Degree    technician   yes
# 71   39    male       divorced  yes              MBA  enterpreneur   yes
# 72   34  female       divorced  yes  Bachelor Degree  enterpreneur   yes
# 73   45    male        married  yes   Masters Degree    technician   yes
# 74   19  female        married   no          Student       student    no
# 75   20    male         single   no          Student       student    no
# 76   24  female       divorced  yes  Bachelor Degree    unemployed   yes
# 77   26    male         single   no  Bachelor Degree    unemployed    no
# 78   20  female        married  yes   Masters Degree        admin.    no
# 79   28  female        married  yes  Bachelor Degree    management    no
# 80   38    male        married  yes  Bachelor Degree     housemaid   yes
# 81   40  female       divorced   no              MBA  enterpreneur    no
# 82   34  female        married  yes   Masters Degree        Doctor    no
# 83   30    male        married  yes   Masters Degree  sales person   yes
# 84   24    male         single   no          Student       student    no
# 85   25    male         single   no  College Diploma       Teacher    no
# 86   48    male         single   no  Bachelor Degree       Teacher   yes
# 87   34  female         single   no   Masters Degree        Doctor    no
# 88   38    male        married  yes   Masters Degree  Sales person   yes
# 89   30  female        married  yes      High School        Lowyer    no
# 90   26    male         single  yes  College Diploma        Lowyer    no
# 91   20    male         single   no      High School        Lowyer    no
# 92   24    male         single   no  Bachelor Degree   CEO company   yes
# 93   28  female         single   no  Bachelor Degree   CEO company    no
# 94   34    male         single  yes              MBA  sales person   yes
# 95   25  female         single   no  Bachelor Degree       doctor.    no
# 96   22  female         single   no          Student       service    no
# 97   21    male        married  yes          Student       student    no
# 98   23  female       divorced  yes  Bachelor Degree  sales person    no
#
#    deposit loan  current loan
# 0      yes  yes        500000
# 1      yes   no             0
# 2       no  yes        390000
# 3       no   no             0
# 4      yes   no             0
# 5      yes   no             0
# 6      yes  yes        100000
# 7       no   no             0
# 8      yes   no             0
# 9      yes  yes         70000
# 10     yes   no             0
# 11      no   no             0
# 12     yes  yes        850000
# 13     yes  yes        455100
# 14      no  yes        137000
# 15     yes   no             0
# 16      no   no             0
# 17     yes   no             0
# 18      no   no             0
# 19      no  yes        900000
# 20     yes   no             0
# 21      no   no             0
# 22      no  yes        600000
# 23     yes   no             0
# 24     yes   no             0
# 25     yes  yes        123400
# 26      no   no             0
# 27     yes   no             0
# 28      no   no             0
# 29     yes  yes        450000
# ..     ...  ...           ...
# 69      no  yes        670000
# 70      no  yes        800000
# 71      no   no             0
# 72     yes   no             0
# 73     yes  yes        740000
# 74     yes   no             0
# 75      no  yes        800000
# 76      no   no             0
# 77     yes  yes       1500000
# 78      no   no             0
# 79     yes  yes       3000000
# 80      no   no             0
# 81     yes  yes        280000
# 82      no  yes        130000
# 83     yes  yes        700000
# 84      no   no             0
# 85     yes   no             0
# 86     yes   no             0
# 87      no   no             0
# 88      no   no             0
# 89     yes  yes        123900
# 90     yes   no             0
# 91     yes  yes        377000
# 92     yes   no             0
# 93     yes  yes       2000000
# 94     yes   no             0
# 95      no  yes        950000
# 96     yes   no             0
# 97      no   no             0
# 98     yes  yes        200000
#
# [99 rows x 10 columns]

# %% [markdown]
# In this table we can see all 99 observations( respondents) by 9 different charasteristics in columns.

# %%
assel.head(13)
# Out:
#     age  gender marital status kids        education           job house  \
# 0    30  female        married  yes  Bachelor Degree  sales person    no
# 1    44    male        married  yes   Masters Degree       teacher   yes
# 2    30    male         single   no              MBA        doctor    no
# 3    20    male         single   no          Student       student    no
# 4    33  female       divorced  yes  Bachelor Degree     housemaid   yes
# 5    21  female        married   no  College Diploma       teacher    no
# 6    26    male         single   no   Masters Degree        doctor    no
# 7    20  female         single   no          Student       student    no
# 8    37  female        married  yes  College Diploma     housemaid   yes
# 9    34    male       divorced  yes              MBA      marketer   yes
# 10   30    male         single   no   Masters Degree      marketer    no
# 11   45    male        married  yes   Masters Degree    technician   yes
# 12   56  female        married  yes   Masters Degree       service   yes
#
#    deposit loan  current loan
# 0      yes  yes        500000
# 1      yes   no             0
# 2       no  yes        390000
# 3       no   no             0
# 4      yes   no             0
# 5      yes   no             0
# 6      yes  yes        100000
# 7       no   no             0
# 8      yes   no             0
# 9      yes  yes         70000
# 10     yes   no             0
# 11      no   no             0
# 12     yes  yes        850000

# %% [markdown]
# Code 'head' shows first 13 observations,by writing number in () we can put any number and it will change

# %%
assel.tail(13)
# Out:
#     age  gender marital status kids        education           job house  \
# 86   48    male         single   no  Bachelor Degree       Teacher   yes
# 87   34  female         single   no   Masters Degree        Doctor    no
# 88   38    male        married  yes   Masters Degree  Sales person   yes
# 89   30  female        married  yes      High School        Lowyer    no
# 90   26    male         single  yes  College Diploma        Lowyer    no
# 91   20    male         single   no      High School        Lowyer    no
# 92   24    male         single   no  Bachelor Degree   CEO company   yes
# 93   28  female         single   no  Bachelor Degree   CEO company    no
# 94   34    male         single  yes              MBA  sales person   yes
# 95   25  female         single   no  Bachelor Degree       doctor.    no
# 96   22  female         single   no          Student       service    no
# 97   21    male        married  yes          Student       student    no
# 98   23  female       divorced  yes  Bachelor Degree  sales person    no
#
#    deposit loan  current loan
# 86     yes   no             0
# 87      no   no             0
# 88      no   no             0
# 89     yes  yes        123900
# 90     yes   no             0
# 91     yes  yes        377000
# 92     yes   no             0
# 93     yes  yes       2000000
# 94     yes   no             0
# 95      no  yes        950000
# 96     yes   no             0
# 97      no   no             0
# 98     yes  yes        200000

# %% [markdown]
# Tail means last 13 observations in my case

# %%
assel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 10 columns):
# age               99 non-null int64
# gender            99 non-null object
# marital status    99 non-null object
# kids              99 non-null object
# education         99 non-null object
# job               99 non-null object
# house             99 non-null object
# deposit           99 non-null object
# loan              99 non-null object
# current loan      99 non-null int64
# dtypes: int64(2), object(8)
# memory usage: 7.8+ KB

# %% [markdown]
# Info shows us the types of data like int64 and object. 8 of these columns have the data type object,2 of them int64 . Most of these object columns show random text, but there are also some candidates for data type which cause some effects to other variables. Totally in this table there are 10 columns, Info shows us how many non-null values table contain,their provide basic information,however null values make some analysis according to specific problem. In those table we see that there are same count of non-null values and also it’s equal to the 99 rows in data set. DataFrame contains at all 99,so there is no missing value.And we don’t need to replace any missing value. There are some categorical data has some advantages over unstructured,numerical data.

# %%
assel.corr(method= 'pearson')
# Out:
#                    age  current loan
# age           1.000000      0.043383
# current loan  0.043383      1.000000

# %% [markdown]
# 'pearson' shows positive and negative relationships between two variables. Between 0.7 and 1.0 shows positive relationship, and -0.7 and -1.0 negative, 0 is no any relationship.In this case positive

# %%
assel.corr(method= 'kendall')
# Out:
#                    age  current loan
# age           1.000000      0.085154
# current loan  0.085154      1.000000

# %% [markdown]
# 'kendall' shows similarities and dependence between variables.

# %%
assel.describe()
# Out:
#              age  current loan
# count  99.000000  9.900000e+01
# mean   33.555556  3.566717e+05
# std    10.803648  6.161727e+05
# min    18.000000  0.000000e+00
# 25%    25.000000  0.000000e+00
# 50%    31.000000  0.000000e+00
# 75%    40.000000  5.637000e+05
# max    63.000000  3.200000e+06

# %% [markdown]
# This table shows us numeric data description.Each of the description column the data can be divided according to several criteria related respondents.There are some categorical data has some advantages over unstructured,numerical data. 'Count' shows number of rows. 'Mean' shows the average value .'Min'shows number of minimum in the data.'Std' shows the number of different alues from the data.'25%', '50%', '75' shows percentage of clients e.g.75% have age 40.

# %%
assel_vis= sns.barplot(x="education", y="age", data=assel)

# %%
assel_vis= sns.barplot(x="deposit", y="age", data=assel)

# %%
assel_vis= sns.barplot(x="house", y="age", data=assel)

# %%
assel_vis= sns.barplot(x="current loan", y="marital status", data=assel)
